# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1, 2, 3, 4]);

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

plt.plot(x, y);

# %%
# 1st method

fig = plt.figure() # creates a figure
ax = fig.add_subplot() # adds some axes
plt.show()

# %%
# 2nd method

fig = plt.figure() # creates a figure
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y) # add some data
plt.show()

# %%
# 3rd method (recommended)

fig, ax = plt.subplots()
ax.plot(x, y); # add some datas

# %% [markdown]
# # Matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10, 10)) # (width, height)

# 3. Plot data
ax.plot(x, y)

# 4. Customize plot
ax.set(title="Simple plot",
       xlabel="x-axis",
       ylabel="y-axis")

# 5. Share and show (you save the hole figure)
fig.savefig("data/sample-plot.png")

# %% [markdown]
# ## Making figures with NumPy arrays
#
# We want:
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplots

# %%
x = np.linspace(0, 10, 100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
# plot the data and create a line plot

fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
# Use the same data to make scatter

fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
# Anoter scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# Make a plot from dictionary

nut_butter_price = {"Almond butter": 10,
                    "Peanut butter": 8,
                    "Cashew butter": 12}

fig, ax = plt.subplots()
ax.bar(nut_butter_price.keys(), nut_butter_price.values())
ax.set(title="Khant's Nut Butter prices",
       ylabel="Prices ($)");

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_price.keys()), list(nut_butter_price.values()));

# %%
# Make some data for histograms and plot it
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ### Two options for subplots

# %%
# Subplots option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                             ncols=2, 
                                             figsize=(10, 5))

# Plot to each different axis

ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_price.keys(), nut_butter_price.values());
ax4.hist(np.random.randn(1000));

# %%
# Subplots option 2

fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                       figsize=(10, 5))

# Plot to each different index

ax[0, 0].plot(x, x/2)
ax[0, 1].scatter(np.random.random(10), np.random.random(10))
ax[1, 0].bar(nut_butter_price.keys(), nut_butter_price.values())
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from pandas DataFrames

# %%
# Make a DataFrame

car_sales = pd.read_csv("car-sales.csv")

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range("8/6/2022", periods=1000))

ts = ts.cumsum()

ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].replace('[\$\,]', "", regex=True).astype(float)

# %%
car_sales["Price"] = car_sales["Price"].astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2020", periods=len(car_sales))

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x="Sale Date", y="Total Sales");

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
# How about bar graph?

x = np.random.rand(10, 4)

# Turn it into a dataframe
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])

df
# Out:
#           a         b         c         d
# 0  0.980354  0.946646  0.316107  0.503660
# 1  0.030422  0.732711  0.477284  0.274789
# 2  0.992431  0.234928  0.138337  0.086576
# 3  0.050151  0.335799  0.642758  0.489376
# 4  0.410301  0.927915  0.814620  0.419688
# 5  0.754786  0.059800  0.380397  0.062958
# 6  0.996010  0.939656  0.333876  0.570506
# 7  0.306654  0.217832  0.915303  0.897820
# 8  0.579620  0.582833  0.869942  0.243219
# 9  0.832699  0.698299  0.435492  0.507480

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
# How about histogram?

car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
heart_disease = pd.read_csv("heart-disease.csv")

heart_disease.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
heart_disease.head(10).plot();

# %%
heart_disease.head(10).plot.bar();

# %%
heart_disease.age.head(30).plot();

# %% [markdown]
# ### Which one should you use? (pyplot vs matplotlib OO method?)
# * When plotting something quickly, okay to use the pyplot method
# * When plotting something more advanced, use the OO method

# %%
over_50 = heart_disease[heart_disease.age > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
over_50.plot(kind="scatter",
             x='age',
             y='chol',
             c="target",
             figsize=(10, 6));

# %%
fig, ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind="scatter",
             x="age",
             y="chol",
             c="target",
             ax=ax);

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                             ncols=2,
                                             figsize=(10, 4))

ax1.plot(heart_disease.age.head(),
         heart_disease.chol.head());

ax2.bar(heart_disease.age.head(),
        heart_disease.chol.head());

ax3.scatter(heart_disease.age.head(),
            heart_disease.chol.head());

ax4.hist(heart_disease.age.head());

# %%
# 00 method from scratch

fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(x=over_50.age,
                       y=over_50.chol,
                       c=over_50.target);

# Customize the plot
ax.set(title="Heart Disease and Cholesterol",
       xlabel="Age",
       ylabel="Cholesterol")

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal line
ax.axhline(over_50.chol.mean(),
           linestyle="--")

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2,
                                ncols=1,
                                figsize=(10, 10))

# Add data to ax0
scatter = ax0.scatter(x=over_50.age,
                      y=over_50.chol,
                      c=over_50.target)

# Customise ax0
ax0.set(title="Heart Disease and Cholesterol levels",
        xlabel="Age",
        ylabel="Cholestrol")

# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Targets")
# Add a meanline
ax0.axhline(over_50.chol.mean(),
            linestyle="--");

# Add data to ax1
scatter1 = ax1.scatter(x=over_50.age,
                       y=over_50.thalach,
                       c=over_50.target)

# Customise the ax1
ax1.set(title="Heart Disease and Thalach",
        xlabel="Age",
        ylabel="Thalach")
# Add legend to ax1
ax1.legend(*scatter1.legend_elements(), title="Targets")
# Add a meanline
ax1.axhline(over_50.thalach.mean(),
            linestyle=":");

# Add title to the figure
fig.suptitle("Heart Disease Analysis",
             fontsize=16,
             fontweight="bold");

# %% [markdown]
# ## Customizing the plot

# %%
# See the available styles
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# Set the style

plt.style.use("seaborn-whitegrid")

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500

# %%
ax = car_sales["Odometer (KM)"].plot()

# %%
plt.style.use("seaborn")

# %%
ax = car_sales["Odometer (KM)"].plot(kind="bar")

# %%
# Add the data 
ax = plt.bar(car_sales.Colour,
             car_sales.Price)

# Customize the ax
plt.title("Analysis between colors and price")
plt.xlabel("Colors")
plt.ylabel("Price");

plt.axhline(car_sales.Price.mean(),
            linestyle="--",
            color="Red")

# %%
# Set the plot style
plt.style.use("seaborn-whitegrid")

fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(x=over_50.age,
                     y=over_50.chol,
                     c=over_50.target,
                     cmap="winter");

# Customize the plot
ax.set(title="Heart Disease and Cholesterol",
       xlabel="Age",
       ylabel="Cholesterol")

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target")

# Change x axis limits
ax.set_xlim([50, 80])

# Add a horizontal line
ax.axhline(over_50.chol.mean(),
           linestyle="--");

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10, 10))

# Add data to ax0
scatter = ax0.scatter(x=over_50.age,
                      y=over_50.chol,
                      c=over_50.target,
                      cmap="winter")

# Customise ax0
ax0.set(title="Heart Disease and Cholesterol levels",
        xlabel="Age",
        ylabel="Cholestrol")

# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Targets")
# Change ax0 x axis limits
ax0.set_xlim([50, 80])
# Add a meanline
ax0.axhline(over_50.chol.mean(),
            linestyle="--",
            color="red");

# Add data to ax1
scatter1 = ax1.scatter(x=over_50.age,
                       y=over_50.thalach,
                       c=over_50.target,
                       cmap="winter")

# Customise the ax1
ax1.set(title="Heart Disease and Thalach",
        xlabel="Age",
        ylabel="Thalach")
# Add legend to ax1
ax1.legend(*scatter1.legend_elements(), title="Targets")
# Change the ax1 x limit
ax1.set_xlim([50, 80])
# Change the ax0 x limit
ax1.set_ylim([60, 200])
# Add a meanline
ax1.axhline(over_50.thalach.mean(),
            linestyle=":",
            color="red");

# Add title to the figure
fig.suptitle("Heart Disease Analysis",
             fontsize=16,
             fontweight="bold");

# %%
fig.savefig("heart-disease-analysis-saved-with-code.png")
