# %%
import pandas as pd

# %%
# 2 main data types
# They are Series and DataFrame. Series take python list and DataFrame take python dictionary.

series = pd.Series(["BMW", "Toyota", "Honda"])
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# Series take python list.
# series = 1-dimensional

# %%
colors = pd.Series(["Red", "Blue", "White"])
colors
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# DataFrame = 2-dimensional
# DataFrame take python dictionary.

car_data = pd.DataFrame({"Car make": series, "Color": colors})
car_data
# Out:
#   Car make  Color
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
# Import Data
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting a dataframe
car_sales.to_csv("exported-car-sales.csv", index=False) 
# in this place, if we don't type index=False, panda will export the index number too.

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe Data

# %%
# Attribute
car_sales.dtypes

# Function
# car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# /var/folders/_c/3x08c65d7gl4gv3jgfmwl7c00000gn/T/ipykernel_6931/4073448239.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   car_sales.mean()
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales["Doors"].mean()
# Out:
# 4.0

# %%
car_prices = pd.Series([2000, 40300, 2220])
car_prices.mean()
# Out:
# 14840.0

# %%
car_prices.sum()
# Out:
# 44520

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.tail(2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc and .iloc

# .loc is short form of location
animals = pd.Series(["cat","bird", "dog", "snake", "panda"],
                   index=[1, 3, 9, 8, 3])

# %%
animals
# Out:
# 1      cat
# 3     bird
# 9      dog
# 8    snake
# 3    panda
# dtype: object

# %%
animals.loc[3]
# Out:
# 3     bird
# 3    panda
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'snake'

# %%
animals.loc[9]
# Out:
# 'dog'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[2]
# Out:
# Make                Toyota
# Colour                Blue
# Odometer (KM)        32549
# Doors                    3
# Price            $7,000.00
# Name: 2, dtype: object

# %%
# .iloc refers to postion of the index, it shows the value of input index.

# In this place, we notice .loc show the loction of input index and show the output, 
# but in .iloc it shows the value of input index (it start from 0).

animals.iloc[3]
# Out:
# 'snake'

# %%
animals
# Out:
# 1      cat
# 3     bird
# 9      dog
# 8    snake
# 3    panda
# dtype: object

# %%
car_sales.iloc[5]
# Out:
# Make                Toyota
# Colour               Green
# Odometer (KM)        99213
# Doors                    4
# Price            $4,500.00
# Name: 5, dtype: object

# %%
car_sales.loc[:3] # this's because it shows the input index 0 to 3. So, it show from 0 to index 4.
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.iloc[:3] # this's because it shows the position of input value, 3, So it shows from 0 to index 2
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
# above two conditionals are tures. We can use us we like. The different between that is when there is a space in our
# dot notation input, we cannot use it. Let's see.

# car_sales.Odometer (KM), in this stage, we can't.

# So it is domand in our conditions.

car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales[car_sales.Colour == "White"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales[car_sales["Odometer (KM)"] > 144444]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
pd.crosstab(car_sales["Doors"], car_sales["Odometer (KM)"])
# Out:
# Odometer (KM)  11179   31600   32549   45698   54738   60000   87899   99213   \
# Doors
# 3                   0       0       1       0       0       0       0       0
# 4                   0       1       0       1       1       1       1       1
# 5                   1       0       0       0       0       0       0       0
#
# Odometer (KM)  150043  213095
# Doors
# 3                   0       0
# 4                   1       1
# 5                   0       0

# %%
# Groupby

car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales.groupby(["Make"]).sum()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW             11179      5
# Honda          188335     12
# Nissan         244695      8
# Toyota         341805     15

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
# dataframe["amount"] = dataframe["amount"].str.replace('[\$\,\.]', '').astype(int)

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]', "").astype(float)

# car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)
# Out:
# /var/folders/_c/3x08c65d7gl4gv3jgfmwl7c00000gn/T/ipykernel_6931/2474026752.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]', "").astype(float)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales.plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Manipulating Data

# %%
car_sales.Make.str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales.Make.str.upper()
# Out:
# 0    TOYOTA
# 1     HONDA
# 2    TOYOTA
# 3       BMW
# 4    NISSAN
# 5    TOYOTA
# 6     HONDA
# 7     HONDA
# 8    TOYOTA
# 9    NISSAN
# Name: Make, dtype: object

# %%
car_sales.Make = car_sales.Make.str.upper()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  TOYOTA  White         150043      4   4000.0
# 1   HONDA    Red          87899      4   5000.0
# 2  TOYOTA   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  NISSAN  White         213095      4   3500.0
# 5  TOYOTA  Green          99213      4   4500.0
# 6   HONDA   Blue          45698      4   7500.0
# 7   HONDA   Blue          54738      4   7000.0
# 8  TOYOTA  White          60000      4   6250.0
# 9  NISSAN  White          31600      4   9700.0

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.Odometer.fillna(4)
# Out:
# 0    150043.0
# 1     87899.0
# 2         4.0
# 3     11179.0
# 4    213095.0
# 5         4.0
# 6         4.0
# 7         4.0
# 8     60000.0
# 9     31600.0
# Name: Odometer, dtype: float64

# %%
car_sales_missing.Odometer.fillna(car_sales_missing.Odometer.mean(),
                                 inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing.to_csv("car_sales_missing_edited.csv")

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.isnull()
# Out:
#     Make  Colour  Odometer  Doors  Price
# 0  False   False     False  False  False
# 1  False   False     False  False  False
# 2  False   False      True  False  False
# 3  False   False     False  False  False
# 4  False   False     False  False  False
# 5  False   False      True  False  False
# 6  False    True      True  False  False
# 7  False   False      True  False   True
# 8  False   False     False   True   True
# 9   True   False     False  False  False

# %%
odometer_missing = pd.isnull(car_sales_missing["Odometer"])

# %%
odometer_missing
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8    False
# 9    False
# Name: Odometer, dtype: bool

# %%
car_sales_missing["Odometer"] = odometer_missing

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White     False    4.0   $4,000
# 1   Honda    Red     False    4.0   $5,000
# 2  Toyota   Blue      True    3.0   $7,000
# 3     BMW  Black     False    5.0  $22,000
# 4  Nissan  White     False    4.0   $3,500
# 5  Toyota  Green      True    4.0   $4,500
# 6   Honda    NaN      True    4.0   $7,500
# 7   Honda   Blue      True    4.0      NaN
# 8  Toyota  White     False    NaN      NaN
# 9     NaN  White     False    4.0   $9,700

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  TOYOTA  White         150043      4   4000.0
# 1   HONDA    Red          87899      4   5000.0
# 2  TOYOTA   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  NISSAN  White         213095      4   3500.0
# 5  TOYOTA  Green          99213      4   4500.0
# 6   HONDA   Blue          45698      4   7500.0
# 7   HONDA   Blue          54738      4   7000.0
# 8  TOYOTA  White          60000      4   6250.0
# 9  NISSAN  White          31600      4   9700.0

# %%
# Column from Series

seats_column = pd.Series([5, 5, 5, 5, 5])

# New column with seat
car_sales["Seat"] = seats_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seat
# 0  TOYOTA  White         150043      4   4000.0   5.0
# 1   HONDA    Red          87899      4   5000.0   5.0
# 2  TOYOTA   Blue          32549      3   7000.0   5.0
# 3     BMW  Black          11179      5  22000.0   5.0
# 4  NISSAN  White         213095      4   3500.0   5.0
# 5  TOYOTA  Green          99213      4   4500.0   NaN
# 6   HONDA   Blue          45698      4   7500.0   NaN
# 7   HONDA   Blue          54738      4   7000.0   NaN
# 8  TOYOTA  White          60000      4   6250.0   NaN
# 9  NISSAN  White          31600      4   9700.0   NaN

# %%
car_sales.fillna(5, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seat
# 0  TOYOTA  White         150043      4   4000.0   5.0
# 1   HONDA    Red          87899      4   5000.0   5.0
# 2  TOYOTA   Blue          32549      3   7000.0   5.0
# 3     BMW  Black          11179      5  22000.0   5.0
# 4  NISSAN  White         213095      4   3500.0   5.0
# 5  TOYOTA  Green          99213      4   4500.0   5.0
# 6   HONDA   Blue          45698      4   7500.0   5.0
# 7   HONDA   Blue          54738      4   7000.0   5.0
# 8  TOYOTA  White          60000      4   6250.0   5.0
# 9  NISSAN  White          31600      4   9700.0   5.0

# %%
# Column from Python list

fuel_economy = [7.5, 3.5, 3.8, 8.3, 2.9, 4.3,  4, 6, 3, 2.2]

car_sales["Fuel per 100KM"] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seat  Fuel per 100KM
# 0  TOYOTA  White         150043      4   4000.0   5.0             7.5
# 1   HONDA    Red          87899      4   5000.0   5.0             3.5
# 2  TOYOTA   Blue          32549      3   7000.0   5.0             3.8
# 3     BMW  Black          11179      5  22000.0   5.0             8.3
# 4  NISSAN  White         213095      4   3500.0   5.0             2.9
# 5  TOYOTA  Green          99213      4   4500.0   5.0             4.3
# 6   HONDA   Blue          45698      4   7500.0   5.0             4.0
# 7   HONDA   Blue          54738      4   7000.0   5.0             6.0
# 8  TOYOTA  White          60000      4   6250.0   5.0             3.0
# 9  NISSAN  White          31600      4   9700.0   5.0             2.2

# %%
car_sales["Total fuel used"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seat  Fuel per 100KM  \
# 0  TOYOTA  White         150043      4   4000.0   5.0             7.5
# 1   HONDA    Red          87899      4   5000.0   5.0             3.5
# 2  TOYOTA   Blue          32549      3   7000.0   5.0             3.8
# 3     BMW  Black          11179      5  22000.0   5.0             8.3
# 4  NISSAN  White         213095      4   3500.0   5.0             2.9
# 5  TOYOTA  Green          99213      4   4500.0   5.0             4.3
# 6   HONDA   Blue          45698      4   7500.0   5.0             4.0
# 7   HONDA   Blue          54738      4   7000.0   5.0             6.0
# 8  TOYOTA  White          60000      4   6250.0   5.0             3.0
# 9  NISSAN  White          31600      4   9700.0   5.0             2.2
#
#    Total fuel used
# 0        11253.225
# 1         3076.465
# 2         1236.862
# 3          927.857
# 4         6179.755
# 5         4266.159
# 6         1827.920
# 7         3284.280
# ...

# %%
car_sales["Total fuel used (L)"] = car_sales["Total fuel used"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seat  Fuel per 100KM  \
# 0  TOYOTA  White         150043      4   4000.0   5.0             7.5
# 1   HONDA    Red          87899      4   5000.0   5.0             3.5
# 2  TOYOTA   Blue          32549      3   7000.0   5.0             3.8
# 3     BMW  Black          11179      5  22000.0   5.0             8.3
# 4  NISSAN  White         213095      4   3500.0   5.0             2.9
# 5  TOYOTA  Green          99213      4   4500.0   5.0             4.3
# 6   HONDA   Blue          45698      4   7500.0   5.0             4.0
# 7   HONDA   Blue          54738      4   7000.0   5.0             6.0
# 8  TOYOTA  White          60000      4   6250.0   5.0             3.0
# 9  NISSAN  White          31600      4   9700.0   5.0             2.2
#
#    Total fuel used  Total fuel used (L)
# 0        11253.225            11253.225
# 1         3076.465             3076.465
# 2         1236.862             1236.862
# ...

# %%
car_sales.drop("Total fuel used", axis=1, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seat  Fuel per 100KM  \
# 0  TOYOTA  White         150043      4   4000.0   5.0             7.5
# 1   HONDA    Red          87899      4   5000.0   5.0             3.5
# 2  TOYOTA   Blue          32549      3   7000.0   5.0             3.8
# 3     BMW  Black          11179      5  22000.0   5.0             8.3
# 4  NISSAN  White         213095      4   3500.0   5.0             2.9
# 5  TOYOTA  Green          99213      4   4500.0   5.0             4.3
# 6   HONDA   Blue          45698      4   7500.0   5.0             4.0
# 7   HONDA   Blue          54738      4   7000.0   5.0             6.0
# 8  TOYOTA  White          60000      4   6250.0   5.0             3.0
# 9  NISSAN  White          31600      4   9700.0   5.0             2.2
#
#    Total fuel used (L)
# 0            11253.225
# 1             3076.465
# 2             1236.862
# 3              927.857
# 4             6179.755
# 5             4266.159
# 6             1827.920
# ...

# %%
# Create column from single column

car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seat  Fuel per 100KM  \
# 0  TOYOTA  White         150043      4   4000.0   5.0             7.5
# 1   HONDA    Red          87899      4   5000.0   5.0             3.5
# 2  TOYOTA   Blue          32549      3   7000.0   5.0             3.8
# 3     BMW  Black          11179      5  22000.0   5.0             8.3
# 4  NISSAN  White         213095      4   3500.0   5.0             2.9
# 5  TOYOTA  Green          99213      4   4500.0   5.0             4.3
# 6   HONDA   Blue          45698      4   7500.0   5.0             4.0
# 7   HONDA   Blue          54738      4   7000.0   5.0             6.0
# 8  TOYOTA  White          60000      4   6250.0   5.0             3.0
# 9  NISSAN  White          31600      4   9700.0   5.0             2.2
#
#    Total fuel used (L)  Number of wheels
# 0            11253.225                 4
# 1             3076.465                 4
# 2             1236.862                 4
# ...

# %%
car_sales["Passed road saftey"] = True

# %%
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)            int64
# Doors                    int64
# Price                  float64
# Seat                   float64
# Fuel per 100KM         float64
# Total fuel used (L)    float64
# Number of wheels         int64
# Passed road saftey        bool
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seat  Fuel per 100KM  \
# 0  TOYOTA  White         150043      4   4000.0   5.0             7.5
# 1   HONDA    Red          87899      4   5000.0   5.0             3.5
# 2  TOYOTA   Blue          32549      3   7000.0   5.0             3.8
# 3     BMW  Black          11179      5  22000.0   5.0             8.3
# 4  NISSAN  White         213095      4   3500.0   5.0             2.9
# 5  TOYOTA  Green          99213      4   4500.0   5.0             4.3
# 6   HONDA   Blue          45698      4   7500.0   5.0             4.0
# 7   HONDA   Blue          54738      4   7000.0   5.0             6.0
# 8  TOYOTA  White          60000      4   6250.0   5.0             3.0
# 9  NISSAN  White          31600      4   9700.0   5.0             2.2
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0            11253.225                 4                True
# 1             3076.465                 4                True
# ...

# %%
pd.crosstab(car_sales["Number of wheels"], car_sales["Price"])
# Out:
# Price             3500.0   4000.0   4500.0   5000.0   6250.0   7000.0   \
# Number of wheels
# 4                       1        1        1        1        1        2
#
# Price             7500.0   9700.0   22000.0
# Number of wheels
# 4                       1        1        1

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors         Price  Seat  Fuel per 100KM  \
# count      10.000000  10.000000     10.000000  10.0       10.000000
# mean    78601.400000   4.000000   7645.000000   5.0        4.550000
# std     61983.471735   0.471405   5379.407753   0.0        2.042466
# min     11179.000000   3.000000   3500.000000   5.0        2.200000
# 25%     35836.250000   4.000000   4625.000000   5.0        3.125000
# 50%     57369.000000   4.000000   6625.000000   5.0        3.900000
# 75%     96384.500000   4.000000   7375.000000   5.0        5.575000
# max    213095.000000   5.000000  22000.000000   5.0        8.300000
#
#        Total fuel used (L)  Number of wheels
# count             10.00000              10.0
# mean            3454.77230               4.0
# std             3221.05079               0.0
# min              695.20000               4.0
# 25%             1377.64650               4.0
# 50%             2452.19250               4.0
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seat  Fuel per 100KM  \
# 0  TOYOTA  White         150043      4   4000.0   5.0             7.5
# 1   HONDA    Red          87899      4   5000.0   5.0             3.5
# 2  TOYOTA   Blue          32549      3   7000.0   5.0             3.8
# 3     BMW  Black          11179      5  22000.0   5.0             8.3
# 4  NISSAN  White         213095      4   3500.0   5.0             2.9
# 5  TOYOTA  Green          99213      4   4500.0   5.0             4.3
# 6   HONDA   Blue          45698      4   7500.0   5.0             4.0
# 7   HONDA   Blue          54738      4   7000.0   5.0             6.0
# 8  TOYOTA  White          60000      4   6250.0   5.0             3.0
# 9  NISSAN  White          31600      4   9700.0   5.0             2.2
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0            11253.225                 4                True
# 1             3076.465                 4                True
# ...

# %%
car_sale_shuffled = car_sales.sample(frac=1)

car_sale_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seat  Fuel per 100KM  \
# 1   HONDA    Red          87899      4   5000.0   5.0             3.5
# 7   HONDA   Blue          54738      4   7000.0   5.0             6.0
# 2  TOYOTA   Blue          32549      3   7000.0   5.0             3.8
# 0  TOYOTA  White         150043      4   4000.0   5.0             7.5
# 3     BMW  Black          11179      5  22000.0   5.0             8.3
# 9  NISSAN  White          31600      4   9700.0   5.0             2.2
# 8  TOYOTA  White          60000      4   6250.0   5.0             3.0
# 4  NISSAN  White         213095      4   3500.0   5.0             2.9
# 5  TOYOTA  Green          99213      4   4500.0   5.0             4.3
# 6   HONDA   Blue          45698      4   7500.0   5.0             4.0
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 1             3076.465                 4                True
# 7             3284.280                 4                True
# ...

# %%
# Only select 20% of data

car_sale_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seat  Fuel per 100KM  \
# 6   HONDA   Blue          45698      4  7500.0   5.0             4.0
# 2  TOYOTA   Blue          32549      3  7000.0   5.0             3.8
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 6             1827.920                 4                True
# 2             1236.862                 4                True

# %%
car_sale_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seat  Fuel per 100KM  \
# 1   HONDA    Red          87899      4   5000.0   5.0             3.5
# 7   HONDA   Blue          54738      4   7000.0   5.0             6.0
# 2  TOYOTA   Blue          32549      3   7000.0   5.0             3.8
# 0  TOYOTA  White         150043      4   4000.0   5.0             7.5
# 3     BMW  Black          11179      5  22000.0   5.0             8.3
# 9  NISSAN  White          31600      4   9700.0   5.0             2.2
# 8  TOYOTA  White          60000      4   6250.0   5.0             3.0
# 4  NISSAN  White         213095      4   3500.0   5.0             2.9
# 5  TOYOTA  Green          99213      4   4500.0   5.0             4.3
# 6   HONDA   Blue          45698      4   7500.0   5.0             4.0
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 1             3076.465                 4                True
# 7             3284.280                 4                True
# ...

# %%
car_sale_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sale_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seat  Fuel per 100KM  \
# 0   HONDA    Red          87899      4   5000.0   5.0             3.5
# 1   HONDA   Blue          54738      4   7000.0   5.0             6.0
# 2  TOYOTA   Blue          32549      3   7000.0   5.0             3.8
# 3  TOYOTA  White         150043      4   4000.0   5.0             7.5
# 4     BMW  Black          11179      5  22000.0   5.0             8.3
# 5  NISSAN  White          31600      4   9700.0   5.0             2.2
# 6  TOYOTA  White          60000      4   6250.0   5.0             3.0
# 7  NISSAN  White         213095      4   3500.0   5.0             2.9
# 8  TOYOTA  Green          99213      4   4500.0   5.0             4.3
# 9   HONDA   Blue          45698      4   7500.0   5.0             4.0
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0             3076.465                 4                True
# 1             3284.280                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seat  Fuel per 100KM  \
# 0  TOYOTA  White         150043      4   4000.0   5.0             7.5
# 1   HONDA    Red          87899      4   5000.0   5.0             3.5
# 2  TOYOTA   Blue          32549      3   7000.0   5.0             3.8
# 3     BMW  Black          11179      5  22000.0   5.0             8.3
# 4  NISSAN  White         213095      4   3500.0   5.0             2.9
# 5  TOYOTA  Green          99213      4   4500.0   5.0             4.3
# 6   HONDA   Blue          45698      4   7500.0   5.0             4.0
# 7   HONDA   Blue          54738      4   7000.0   5.0             6.0
# 8  TOYOTA  White          60000      4   6250.0   5.0             3.0
# 9  NISSAN  White          31600      4   9700.0   5.0             2.2
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0            11253.225                 4                True
# 1             3076.465                 4                True
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x / 1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seat  Fuel per 100KM  \
# 0  TOYOTA  White      93776.875      4   4000.0   5.0             7.5
# 1   HONDA    Red      54936.875      4   5000.0   5.0             3.5
# 2  TOYOTA   Blue      20343.125      3   7000.0   5.0             3.8
# 3     BMW  Black       6986.875      5  22000.0   5.0             8.3
# 4  NISSAN  White     133184.375      4   3500.0   5.0             2.9
# 5  TOYOTA  Green      62008.125      4   4500.0   5.0             4.3
# 6   HONDA   Blue      28561.250      4   7500.0   5.0             4.0
# 7   HONDA   Blue      34211.250      4   7000.0   5.0             6.0
# 8  TOYOTA  White      37500.000      4   6250.0   5.0             3.0
# 9  NISSAN  White      19750.000      4   9700.0   5.0             2.2
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0            11253.225                 4                True
# 1             3076.465                 4                True
# ...

# %%
car_sales.rename(columns = {"Odometer (KM)": "Odometer (M)"}, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (M)  Doors    Price  Seat  Fuel per 100KM  \
# 0  TOYOTA  White     93776.875      4   4000.0   5.0             7.5
# 1   HONDA    Red     54936.875      4   5000.0   5.0             3.5
# 2  TOYOTA   Blue     20343.125      3   7000.0   5.0             3.8
# 3     BMW  Black      6986.875      5  22000.0   5.0             8.3
# 4  NISSAN  White    133184.375      4   3500.0   5.0             2.9
# 5  TOYOTA  Green     62008.125      4   4500.0   5.0             4.3
# 6   HONDA   Blue     28561.250      4   7500.0   5.0             4.0
# 7   HONDA   Blue     34211.250      4   7000.0   5.0             6.0
# 8  TOYOTA  White     37500.000      4   6250.0   5.0             3.0
# 9  NISSAN  White     19750.000      4   9700.0   5.0             2.2
#
#    Total fuel used (L)  Number of wheels  Passed road saftey
# 0            11253.225                 4                True
# 1             3076.465                 4                True
# ...
