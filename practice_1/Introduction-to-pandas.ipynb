# %%
import pandas as pd

# %% [markdown]
# There are Series and DataFrame in Pandas. `Series` take python list and `DataFrame` take python dictionary.

# %%
series = pd.Series(["BMW", "Tesla", "Honda"])
series
# Out:
# 0      BMW
# 1    Tesla
# 2    Honda
# dtype: object

# %% [markdown]
# Series is one dimensional

# %%
colors = pd.Series(["Blue", "Red", "White"])
colors
# Out:
# 0     Blue
# 1      Red
# 2    White
# dtype: object

# %% [markdown]
# DataFrame is two dimensional

# %%
car_data = pd.DataFrame({
    "Car make": series,
    "Color": colors
})

car_data
# Out:
#   Car make  Color
# 0      BMW   Blue
# 1    Tesla    Red
# 2    Honda  White

# %%
# Import Data

car_sales = pd.read_csv("../data/car-sales-extended.csv")

car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
# Exporting a dataframe
car_sales.to_csv("exported-car-sales.csv", index=False)

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")

exported_car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## Describe Data

# %%
# Attribue
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int64
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
car_sales.describe()
# Out:
#        Odometer (KM)        Doors         Price
# count    1000.000000  1000.000000   1000.000000
# mean   131073.708000     4.014000  16045.665000
# std     68859.723885     0.379405   8630.794219
# min     10148.000000     3.000000   2796.000000
# 25%     71238.000000     4.000000   9481.500000
# 50%    131202.000000     4.000000  14264.000000
# 75%    192372.750000     4.000000  20738.750000
# max    249860.000000     5.000000  52458.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           1000 non-null   object
#  1   Colour         1000 non-null   object
#  2   Odometer (KM)  1000 non-null   int64
#  3   Doors          1000 non-null   int64
#  4   Price          1000 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %%
car_sales.mean()
# Out:
# /var/folders/_c/3x08c65d7gl4gv3jgfmwl7c00000gn/T/ipykernel_6306/4073448239.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   car_sales.mean()
# Odometer (KM)    131073.708
# Doors                 4.014
# Price             16045.665
# dtype: float64

# %%
car_sales["Doors"].mean()
# Out:
# 4.014

# %%
car_prices = pd.Series([2000, 40300, 2220])
car_prices.mean()
# Out:
# 14840.0

# %%
car_prices.sum()
# Out:
# 44520

# %%
car_sales.sum()
# Out:
# Make             HondaBMWHondaToyotaNissanHondaToyotaHondaNissa...
# Colour           WhiteBlueWhiteWhiteBlueRedBlueWhiteWhiteBlueWh...
# Odometer (KM)                                            131073708
# Doors                                                         4014
# Price                                                     16045665
# dtype: object

# %%
len(car_sales)
# Out:
# 1000

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434
# 4  Nissan   Blue         181577      3  14043

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434
# 4  Nissan   Blue         181577      3  14043
# 5   Honda    Red          42652      4  23883
# 6  Toyota   Blue         163453      4   8473

# %%
car_sales.tail()
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732

# %%
car_sales.tail(8)
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 992   Honda  Green          54721      4  27419
# 993  Nissan  Black         162523      4   4696
# 994     BMW   Blue         163322      3  31666
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732

# %%
# .loc and .iloc

# .loc is short form of location
animals = pd.Series(["cat", "bird", "dog", "snake", "panda"],
                    index=[1, 3, 9, 8, 3])

# %%
animals
# Out:
# 1      cat
# 3     bird
# 9      dog
# 8    snake
# 3    panda
# dtype: object

# %%
animals.loc[3]
# Out:
# 3     bird
# 3    panda
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'snake'

# %%
animals.loc[9]
# Out:
# 'dog'

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
car_sales.loc[88]
# Out:
# Make             Nissan
# Colour              Red
# Odometer (KM)     61892
# Doors                 4
# Price             18160
# Name: 88, dtype: object

# %%
car_sales.iloc[4]
# Out:
# Make             Nissan
# Colour             Blue
# Odometer (KM)    181577
# Doors                 3
# Price             14043
# Name: 4, dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434

# %%
car_sales.iloc[:3]
# Out:
#     Make Colour  Odometer (KM)  Doors  Price
# 0  Honda  White          35431      4  15323
# 1    BMW   Blue         192714      5  19943
# 2  Honda  White          84714      4  28343

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 3    Toyota  White         154365      4  13434
# 6    Toyota   Blue         163453      4   8473
# 15   Toyota   Blue         205592      4  16290
# 16   Toyota    Red          96742      4  34465
# 20   Toyota   Blue         124844      4  24130
# ..      ...    ...            ...    ...    ...
# 983  Toyota    Red         183330      4  14671
# 989  Toyota    Red          41735      4  13928
# 990  Toyota  White         173408      4   8082
# 995  Toyota  Black          35820      4  32042
# 999  Toyota   Blue         248360      4  12732
#
# [398 rows x 5 columns]

# %%
car_sales[car_sales["Colour"] == "White"]
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 7     Honda  White          43120      4  20306
# 8    Nissan  White         130538      4   9374
# ..      ...    ...            ...    ...    ...
# 986   Honda  White          71934      4  26882
# 987   Honda  White         215235      4   3825
# 990  Toyota  White         173408      4   8082
# 996  Nissan  White         155144      3   5716
# 998   Honda  White         215883      4   4001
#
# [407 rows x 5 columns]

# %%
car_sales[car_sales["Odometer (KM)"] > 144444]
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 1       BMW   Blue         192714      5  19943
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# 6    Toyota   Blue         163453      4   8473
# 10   Nissan  White         167421      4  16259
# ..      ...    ...            ...    ...    ...
# 993  Nissan  Black         162523      4   4696
# 994     BMW   Blue         163322      3  31666
# 996  Nissan  White         155144      3   5716
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [451 rows x 5 columns]

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors    3    4   5
# Make
# BMW     21    0  79
# Honda    0  304   0
# Nissan  44  154   0
# Toyota   0  398   0

# %%
pd.crosstab(car_sales["Doors"], car_sales["Odometer (KM)"])
# Out:
# Odometer (KM)  10148   10217   10247   10953   10954   11035   11049   11119   \
# Doors
# 3                   0       0       0       0       0       0       1       0
# 4                   1       1       1       1       1       1       0       1
# 5                   0       0       0       0       0       0       0       0
#
# Odometer (KM)  12141   13050   ...  247869  248301  248360  248416  248447  \
# Doors                          ...
# 3                   0       0  ...       0       0       0       0       0
# 4                   1       1  ...       1       1       1       1       1
# 5                   0       0  ...       0       0       0       0       0
#
# Odometer (KM)  248634  248736  248815  248899  249860
# Doors
# 3                   0       0       0       0       0
# 4                   1       1       1       1       1
# 5                   0       0       0       0       0
#
# [3 rows x 998 columns]

# %%
# Groupby

car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)     Doors         Price
# Make
# BMW     123540.800000  4.580000  27089.830000
# Honda   124667.671053  4.000000  14514.200658
# Nissan  135480.308081  3.777778  13658.368687
# Toyota  135667.223618  4.000000  15628.160804

# %%
car_sales.groupby(["Make"]).sum()
# Out:
#         Odometer (KM)  Doors    Price
# Make
# BMW          12354080    458  2708983
# Honda        37898972   1216  4412317
# Nissan       26825101    748  2704357
# Toyota       53995555   1592  6220008

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales.plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Price"].plot();

# %% [markdown]
# ## Manipulating Data

# %%
car_sales.Make.str.lower()
# Out:
# 0       honda
# 1         bmw
# 2       honda
# 3      toyota
# 4      nissan
#         ...
# 995    toyota
# 996    nissan
# 997    nissan
# 998     honda
# 999    toyota
# Name: Make, Length: 1000, dtype: object

# %%
car_sales["Make"].str.upper()
# Out:
# 0       HONDA
# 1         BMW
# 2       HONDA
# 3      TOYOTA
# 4      NISSAN
#         ...
# 995    TOYOTA
# 996    NISSAN
# 997    NISSAN
# 998     HONDA
# 999    TOYOTA
# Name: Make, Length: 1000, dtype: object

# %%
car_sales["Make"] = car_sales["Make"].str.upper()

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     HONDA  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     HONDA  White          84714      4  28343
# 3    TOYOTA  White         154365      4  13434
# 4    NISSAN   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  TOYOTA  Black          35820      4  32042
# 996  NISSAN  White         155144      3   5716
# 997  NISSAN   Blue          66604      4  31570
# 998   HONDA  White         215883      4   4001
# 999  TOYOTA   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
car_sales_missing = pd.read_csv("../data/car-sales-missing-data.csv")

car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(4)
# Out:
# 0    150043.0
# 1     87899.0
# 2         4.0
# 3     11179.0
# 4    213095.0
# 5         4.0
# 6         4.0
# 7         4.0
# 8     60000.0
# 9     31600.0
# Name: Odometer, dtype: float64

# %%
car_sales_missing.Odometer.fillna(car_sales_missing["Odometer"].mean(),
                                  inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing.to_csv("car_sales_missing_edited.csv")

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
car_sales_missing = pd.read_csv("../data/car-sales-missing-data.csv")

car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.isnull()
# Out:
#     Make  Colour  Odometer  Doors  Price
# 0  False   False     False  False  False
# 1  False   False     False  False  False
# 2  False   False      True  False  False
# 3  False   False     False  False  False
# 4  False   False     False  False  False
# 5  False   False      True  False  False
# 6  False    True      True  False  False
# 7  False   False      True  False   True
# 8  False   False     False   True   True
# 9   True   False     False  False  False

# %%
odometer_missing = pd.isnull(car_sales_missing["Odometer"])

# %%
odometer_missing
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8    False
# 9    False
# Name: Odometer, dtype: bool

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     HONDA  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     HONDA  White          84714      4  28343
# 3    TOYOTA  White         154365      4  13434
# 4    NISSAN   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  TOYOTA  Black          35820      4  32042
# 996  NISSAN  White         155144      3   5716
# 997  NISSAN   Blue          66604      4  31570
# 998   HONDA  White         215883      4   4001
# 999  TOYOTA   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
# Column from Series

seats_column = pd.Series([5, 5, 5, 5, 5])

# New column with seat
car_sales["Seat"] = seats_column

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price  Seat
# 0     HONDA  White          35431      4  15323   5.0
# 1       BMW   Blue         192714      5  19943   5.0
# 2     HONDA  White          84714      4  28343   5.0
# 3    TOYOTA  White         154365      4  13434   5.0
# 4    NISSAN   Blue         181577      3  14043   5.0
# ..      ...    ...            ...    ...    ...   ...
# 995  TOYOTA  Black          35820      4  32042   NaN
# 996  NISSAN  White         155144      3   5716   NaN
# 997  NISSAN   Blue          66604      4  31570   NaN
# 998   HONDA  White         215883      4   4001   NaN
# 999  TOYOTA   Blue         248360      4  12732   NaN
#
# [1000 rows x 6 columns]

# %%
car_sales.fillna(5, inplace=True)

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price  Seat
# 0     HONDA  White          35431      4  15323   5.0
# 1       BMW   Blue         192714      5  19943   5.0
# 2     HONDA  White          84714      4  28343   5.0
# 3    TOYOTA  White         154365      4  13434   5.0
# 4    NISSAN   Blue         181577      3  14043   5.0
# ..      ...    ...            ...    ...    ...   ...
# 995  TOYOTA  Black          35820      4  32042   5.0
# 996  NISSAN  White         155144      3   5716   5.0
# 997  NISSAN   Blue          66604      4  31570   5.0
# 998   HONDA  White         215883      4   4001   5.0
# 999  TOYOTA   Blue         248360      4  12732   5.0
#
# [1000 rows x 6 columns]

# %%
# Column from Python list

fuel_economy = [7.5, 3.5, 3.8, 8.3, 2.9, 4.3,  4, 6, 3, 2.2]

car_sales_missing["Fuel per 100KM"] = fuel_economy

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price  Fuel per 100KM
# 0  Toyota  White  150043.0    4.0   $4,000             7.5
# 1   Honda    Red   87899.0    4.0   $5,000             3.5
# 2  Toyota   Blue       NaN    3.0   $7,000             3.8
# 3     BMW  Black   11179.0    5.0  $22,000             8.3
# 4  Nissan  White  213095.0    4.0   $3,500             2.9
# 5  Toyota  Green       NaN    4.0   $4,500             4.3
# 6   Honda    NaN       NaN    4.0   $7,500             4.0
# 7   Honda   Blue       NaN    4.0      NaN             6.0
# 8  Toyota  White   60000.0    NaN      NaN             3.0
# 9     NaN  White   31600.0    4.0   $9,700             2.2

# %%
car_sales["Total fuel used"] = car_sales["Odometer (KM)"] / 100

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price  Seat  Total fuel used
# 0     HONDA  White          35431      4  15323   5.0           354.31
# 1       BMW   Blue         192714      5  19943   5.0          1927.14
# 2     HONDA  White          84714      4  28343   5.0           847.14
# 3    TOYOTA  White         154365      4  13434   5.0          1543.65
# 4    NISSAN   Blue         181577      3  14043   5.0          1815.77
# ..      ...    ...            ...    ...    ...   ...              ...
# 995  TOYOTA  Black          35820      4  32042   5.0           358.20
# 996  NISSAN  White         155144      3   5716   5.0          1551.44
# 997  NISSAN   Blue          66604      4  31570   5.0           666.04
# 998   HONDA  White         215883      4   4001   5.0          2158.83
# 999  TOYOTA   Blue         248360      4  12732   5.0          2483.60
#
# [1000 rows x 7 columns]

# %%
# Create column from single column

car_sales["Number of wheels"] = 4
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price  Seat  Total fuel used  \
# 0     HONDA  White          35431      4  15323   5.0           354.31
# 1       BMW   Blue         192714      5  19943   5.0          1927.14
# 2     HONDA  White          84714      4  28343   5.0           847.14
# 3    TOYOTA  White         154365      4  13434   5.0          1543.65
# 4    NISSAN   Blue         181577      3  14043   5.0          1815.77
# ..      ...    ...            ...    ...    ...   ...              ...
# 995  TOYOTA  Black          35820      4  32042   5.0           358.20
# 996  NISSAN  White         155144      3   5716   5.0          1551.44
# 997  NISSAN   Blue          66604      4  31570   5.0           666.04
# 998   HONDA  White         215883      4   4001   5.0          2158.83
# 999  TOYOTA   Blue         248360      4  12732   5.0          2483.60
#
#      Number of wheels
# 0                   4
# 1                   4
# 2                   4
# ...

# %%
car_sales["Passed road saftey"] = True

# %%
car_sales.dtypes
# Out:
# Make                   object
# Colour                 object
# Odometer (KM)           int64
# Doors                   int64
# Price                   int64
# Seat                  float64
# Total fuel used       float64
# Number of wheels        int64
# Passed road saftey       bool
# dtype: object

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price  Seat  Total fuel used  \
# 0     HONDA  White          35431      4  15323   5.0           354.31
# 1       BMW   Blue         192714      5  19943   5.0          1927.14
# 2     HONDA  White          84714      4  28343   5.0           847.14
# 3    TOYOTA  White         154365      4  13434   5.0          1543.65
# 4    NISSAN   Blue         181577      3  14043   5.0          1815.77
# ..      ...    ...            ...    ...    ...   ...              ...
# 995  TOYOTA  Black          35820      4  32042   5.0           358.20
# 996  NISSAN  White         155144      3   5716   5.0          1551.44
# 997  NISSAN   Blue          66604      4  31570   5.0           666.04
# 998   HONDA  White         215883      4   4001   5.0          2158.83
# 999  TOYOTA   Blue         248360      4  12732   5.0          2483.60
#
#      Number of wheels  Passed road saftey
# 0                   4                True
# ...

# %%
pd.crosstab(car_sales["Number of wheels"], car_sales["Price"])
# Out:
# Price             2796   3125   3247   3300   3509   3594   3751   3825   \
# Number of wheels
# 4                     1      1      1      1      1      1      1      1
#
# Price             3893   3895   ...  41294  45509  45720  47260  48239  48419  \
# Number of wheels                ...
# 4                     1      1  ...      1      1      1      1      1      1
#
# Price             48686  50822  50868  52458
# Number of wheels
# 4                     1      1      1      1
#
# [1 rows x 984 columns]

# %%
car_sales.describe()
# Out:
#        Odometer (KM)        Doors         Price    Seat  Total fuel used  \
# count    1000.000000  1000.000000   1000.000000  1000.0      1000.000000
# mean   131073.708000     4.014000  16045.665000     5.0      1310.737080
# std     68859.723885     0.379405   8630.794219     0.0       688.597239
# min     10148.000000     3.000000   2796.000000     5.0       101.480000
# 25%     71238.000000     4.000000   9481.500000     5.0       712.380000
# 50%    131202.000000     4.000000  14264.000000     5.0      1312.020000
# 75%    192372.750000     4.000000  20738.750000     5.0      1923.727500
# max    249860.000000     5.000000  52458.000000     5.0      2498.600000
#
#        Number of wheels
# count            1000.0
# mean                4.0
# std                 0.0
# min                 4.0
# 25%                 4.0
# 50%                 4.0
# 75%                 4.0
# max                 4.0

# %%
car_sale_shuffled = car_sales.sample(frac=1)

car_sale_shuffled
# Out:
#        Make Colour  Odometer (KM)  Doors  Price  Seat  Total fuel used  \
# 356  TOYOTA   Blue          96363      4   7469   5.0           963.63
# 443  TOYOTA   Blue          71306      4  23747   5.0           713.06
# 998   HONDA  White         215883      4   4001   5.0          2158.83
# 278   HONDA   Blue         106494      4  17858   5.0          1064.94
# 259   HONDA    Red          61504      4  12046   5.0           615.04
# ..      ...    ...            ...    ...    ...   ...              ...
# 108  NISSAN   Blue         129769      3  15617   5.0          1297.69
# 197  TOYOTA  Green         146940      4  25133   5.0          1469.40
# 268     BMW  White          29534      5  28414   5.0           295.34
# 480  TOYOTA  Black         225991      4  12581   5.0          2259.91
# 573  NISSAN  Green         163080      4   7973   5.0          1630.80
#
#      Number of wheels  Passed road saftey
# 356                 4                True
# ...

# %%
# Only select 20% of data

car_sale_shuffled.sample(frac=0.2)
# Out:
#        Make Colour  Odometer (KM)  Doors  Price  Seat  Total fuel used  \
# 918   HONDA   Blue         228279      4  13519   5.0          2282.79
# 383   HONDA  White         144088      4   5838   5.0          1440.88
# 830  TOYOTA   Blue         190406      4  20867   5.0          1904.06
# 967     BMW  Green          26839      5  15224   5.0           268.39
# 734  TOYOTA  White         235792      4  10726   5.0          2357.92
# ..      ...    ...            ...    ...    ...   ...              ...
# 90   NISSAN  White         197844      4   5776   5.0          1978.44
# 324  TOYOTA  Green         151291      4   6200   5.0          1512.91
# 860  NISSAN  White          61876      4   5922   5.0           618.76
# 832  TOYOTA  White         100107      4   9878   5.0          1001.07
# 340   HONDA  White          80664      4  20981   5.0           806.64
#
#      Number of wheels  Passed road saftey
# 918                 4                True
# ...

# %%
car_sale_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sale_shuffled
# Out:
#        Make Colour  Odometer (KM)  Doors  Price  Seat  Total fuel used  \
# 0    TOYOTA   Blue          96363      4   7469   5.0           963.63
# 1    TOYOTA   Blue          71306      4  23747   5.0           713.06
# 2     HONDA  White         215883      4   4001   5.0          2158.83
# 3     HONDA   Blue         106494      4  17858   5.0          1064.94
# 4     HONDA    Red          61504      4  12046   5.0           615.04
# ..      ...    ...            ...    ...    ...   ...              ...
# 995  NISSAN   Blue         129769      3  15617   5.0          1297.69
# 996  TOYOTA  Green         146940      4  25133   5.0          1469.40
# 997     BMW  White          29534      5  28414   5.0           295.34
# 998  TOYOTA  Black         225991      4  12581   5.0          2259.91
# 999  NISSAN  Green         163080      4   7973   5.0          1630.80
#
#      Number of wheels  Passed road saftey
# 0                   4                True
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x / 1.6)

car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price  Seat  Total fuel used  \
# 0     HONDA  White      22144.375      4  15323   5.0           354.31
# 1       BMW   Blue     120446.250      5  19943   5.0          1927.14
# 2     HONDA  White      52946.250      4  28343   5.0           847.14
# 3    TOYOTA  White      96478.125      4  13434   5.0          1543.65
# 4    NISSAN   Blue     113485.625      3  14043   5.0          1815.77
# ..      ...    ...            ...    ...    ...   ...              ...
# 995  TOYOTA  Black      22387.500      4  32042   5.0           358.20
# 996  NISSAN  White      96965.000      3   5716   5.0          1551.44
# 997  NISSAN   Blue      41627.500      4  31570   5.0           666.04
# 998   HONDA  White     134926.875      4   4001   5.0          2158.83
# 999  TOYOTA   Blue     155225.000      4  12732   5.0          2483.60
#
#      Number of wheels  Passed road saftey
# 0                   4                True
# ...
